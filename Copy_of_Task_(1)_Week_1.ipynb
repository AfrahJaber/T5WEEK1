# %% [markdown]
# <a href="https://colab.research.google.com/github/AfrahJaber/T5Week1/blob/main/Copy_of_Task_(1)_Week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataset Description

# %% [markdown]
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ## 1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Task (1) Dataset.csv')
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df
# Out:
#                      Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 1     1900-01-01 17:02:00      Monday              31-50          Male
# 3     1900-01-01 01:06:00      Sunday              18-30          Male
# 4     1900-01-01 01:06:00      Sunday              18-30          Male
# 7     1900-01-01 17:20:00      Friday              18-30          Male
# 8     1900-01-01 17:20:00      Friday              18-30          Male
# ...                   ...         ...                ...           ...
# 12311 1900-01-01 16:15:00   Wednesday              31-50          Male
# 12312 1900-01-01 18:00:00      Sunday            Unknown          Male
# 12313 1900-01-01 13:55:00      Sunday            Over 51          Male
# 12314 1900-01-01 13:55:00      Sunday              18-30        Female
# 12315 1900-01-01 13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# ...

# %%
df.isnull().sum()
# Out:
# Time                                    0
# Day_of_week                             0
# Age_band_of_driver                      0
# Sex_of_driver                           0
# Educational_level                       0
# Vehicle_driver_relation                 0
# Driving_experience                      0
# Type_of_vehicle                         0
# Owner_of_vehicle                        0
# Service_year_of_vehicle                 0
# Defect_of_vehicle                       0
# Area_accident_occured                   0
# Lanes_or_Medians                        0
# Road_allignment                         0
# Types_of_Junction                       0
# Road_surface_type                       0
# Road_surface_conditions                 0
# Light_conditions                        0
# Weather_conditions                      0
# Type_of_collision                       0
# Number_of_vehicles_involved             0
# Number_of_casualties                    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10706 entries, 1 to 12315
# Data columns (total 39 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Time                                  10706 non-null  datetime64[ns]
#  1   Day_of_week                           10706 non-null  object
#  2   Age_band_of_driver                    10706 non-null  object
#  3   Sex_of_driver                         10706 non-null  object
#  4   Educational_level                     10706 non-null  object
#  5   Vehicle_driver_relation               10706 non-null  object
#  6   Driving_experience                    10706 non-null  object
#  7   Type_of_vehicle                       10706 non-null  object
#  8   Owner_of_vehicle                      10706 non-null  object
#  9   Service_year_of_vehicle               10706 non-null  object
#  10  Defect_of_vehicle                     10706 non-null  object
# ...

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
df['Service_year_of_vehicle'].value_counts()
# Out:
# Service_year_of_vehicle
# Unknown       5721
# 2-5yrs        1636
# Above 10yr    1207
# 5-10yrs       1176
# 1-2yr          703
# Below 1yr      263
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Educational_level']=df['Educational_level'].fillna(df['Educational_level'].mode()[0])

# %%
df['Driving_experience']=df['Driving_experience'].fillna(df['Driving_experience'].mode()[0])
df['Vehicle_driver_relation']=df['Vehicle_driver_relation'].fillna(df['Vehicle_driver_relation'].mode()[0])
# Out:
# <ipython-input-35-58f4f45e4c41>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Driving_experience']=df['Driving_experience'].fillna(df['Driving_experience'].mode()[0])
# <ipython-input-35-58f4f45e4c41>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Vehicle_driver_relation']=df['Vehicle_driver_relation'].fillna(df['Vehicle_driver_relation'].mode()[0])

# %%
df['Service_year_of_vehicle']=df['Service_year_of_vehicle'].fillna(df['Service_year_of_vehicle'].mode()[0])

# %%
df['Defect_of_vehicle']=df['Defect_of_vehicle'].fillna(df['Defect_of_vehicle'].mode()[0])

# %%
df['Type_of_vehicle']=df['Type_of_vehicle'].fillna(df['Type_of_vehicle'].mode()[0])

# %%
df['Types_of_Junction']=df['Types_of_Junction'].fillna(df['Types_of_Junction'].mode()[0])

# %%
df['Work_of_casuality']=df['Work_of_casuality'].fillna(df['Work_of_casuality'].mode()[0])

# %%
df['Fitness_of_casuality']=df['Fitness_of_casuality'].fillna(df['Fitness_of_casuality'].mode()[0])

# %%
df=df.dropna(subset=['Road_allignment','Type_of_collision','Road_surface_conditions'])

# %%
df=df.dropna(subset=['Area_accident_occured','Lanes_or_Medians','Road_surface_type','Vehicle_movement'])

# %%
df=df.dropna(subset=['Owner_of_vehicle'])

# %% [markdown]
# ### Correct any inconsistent data entries
#
# - values out of the ordinary?
# - mixed-case (captial and small)?
# - units?
# - ...etc.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12019 entries, 0 to 12315
# Data columns (total 39 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Time                                  12019 non-null  object
#  1   Day_of_week                           12019 non-null  object
#  2   Age_band_of_driver                    12019 non-null  object
#  3   Sex_of_driver                         12019 non-null  object
#  4   Educational_level                     12019 non-null  object
#  5   Vehicle_driver_relation               12019 non-null  object
#  6   Driving_experience                    12019 non-null  object
#  7   Type_of_vehicle                       12019 non-null  object
#  8   Owner_of_vehicle                      11594 non-null  object
#  9   Service_year_of_vehicle               8206 non-null   object
#  10  Defect_of_vehicle                     7729 non-null   object
# ...

# %%
print(df.groupby('Casualty_severity').size())
# Out:
# Casualty_severity
# 1       25
# 2      751
# 3     6920
# na    4323
# dtype: int64

# %%
df['Casualty_severity'] = df['Casualty_severity'].str.replace('na','3',regex=True)
df['Casualty_severity'] = df['Casualty_severity'].astype(int)

# %%
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S')

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# - numerical but object?
# - date but object?
# - ...etc.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10706 entries, 1 to 12315
# Data columns (total 39 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Time                                  10706 non-null  datetime64[ns]
#  1   Day_of_week                           10706 non-null  object
#  2   Age_band_of_driver                    10706 non-null  object
#  3   Sex_of_driver                         10706 non-null  object
#  4   Educational_level                     10706 non-null  object
#  5   Vehicle_driver_relation               10706 non-null  object
#  6   Driving_experience                    10706 non-null  object
#  7   Type_of_vehicle                       10706 non-null  object
#  8   Owner_of_vehicle                      10706 non-null  object
#  9   Service_year_of_vehicle               10706 non-null  object
#  10  Defect_of_vehicle                     10706 non-null  object
# ...

# %%
df.describe()
# Out:
#                                 Time  Number_of_vehicles_involved  \
# count                          10706                 10706.000000
# mean   1900-01-01 14:17:19.273304576                     2.041098
# min              1900-01-01 00:01:00                     1.000000
# 25%              1900-01-01 10:30:00                     2.000000
# 50%              1900-01-01 15:10:00                     2.000000
# 75%              1900-01-01 18:10:00                     2.000000
# max              1900-01-01 23:59:00                     7.000000
# std                              NaN                     0.689409
#
#        Number_of_casualties  Casualty_severity
# count          10706.000000       10706.000000
# mean               1.549412           2.934242
# min                1.000000           1.000000
# 25%                1.000000           3.000000
# 50%                1.000000           3.000000
# 75%                2.000000           3.000000
# ...

# %%
date_series = pd.to_datetime(df['Time'])

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset

# %%
df['Number_of_vehicles_involved'].sum()
# Out:
# 25133

# %%
df['Number_of_vehicles_involved'].mean()
# Out:
# 2.0406787918155245

# %%
df['Number_of_casualties'].median()
# Out:
# 1.0

# %%
df['Number_of_casualties'].mode()
# Out:
# 0    1
# Name: Number_of_casualties, dtype: int64

# %% [markdown]
# ### Identify and analyze patterns in the data
#
# - heatmap

# %%
import matplotlib.pyplot as plt
import seaborn as sns

corr_matrix = df.corr(numeric_only=True)
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
sns.scatterplot(data=df, x='Age_band_of_driver', y='Type_of_vehicle')
# Out:
# <Axes: xlabel='Age_band_of_driver', ylabel='Type_of_vehicle'>

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
corr_matrix = df.corr(numeric_only=True)
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
plt.bar(df['Age_band_of_driver'].value_counts().index, df['Age_band_of_driver'].value_counts())
# Out:
# <BarContainer object of 5 artists>

# %%
plt.hist(df['Number_of_vehicles_involved'])
plt.show()

# %%
plt.pie(df['Age_band_of_driver'].value_counts(),labels=df['Age_band_of_driver'].value_counts().index)
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>
